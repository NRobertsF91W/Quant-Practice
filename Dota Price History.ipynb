# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date

# %%
item_history = pd.read_csv("Dota Item Price Histories.csv")
display(item_history)
# Out:
#       Unnamed: 0        Date  Price  Number Sold                   Item
# 0              0  2015-09-01  5.692          518  Righteous Thunderbolt
# 1              1  2015-09-02  6.599          173  Righteous Thunderbolt
# 2              2  2015-09-03  6.439          153  Righteous Thunderbolt
# 3              3  2015-09-04  6.287          169  Righteous Thunderbolt
# 4              4  2015-09-05  6.444          169  Righteous Thunderbolt
# ...          ...         ...    ...          ...                    ...
# 9381        9381  2022-05-08  0.400            1      Evergreen Stalker
# 9382        9382  2022-05-08  0.468            2      Evergreen Stalker
# 9383        9383  2022-05-08  0.399            2      Evergreen Stalker
# 9384        9384  2022-05-08  0.380            1      Evergreen Stalker
# 9385        9385  2022-05-08  0.419            2      Evergreen Stalker
#
# [9386 rows x 5 columns]

# %%
data_to_plot = []
for item in np.unique(item_history["Item"]):
    xvals = item_history[item_history["Item"] == item]["Date"].to_numpy()
    yvals = item_history[item_history["Item"] == item]["Price"].to_numpy()
    data_to_plot.append([xvals,yvals])
    
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
for m,list in enumerate(data_to_plot):
    ax1.plot(list[0],list[1], label= np.unique(item_history["Item"])[m])

ax1.set_xlabel("Date")
ax1.set_ylabel("Price ($)")
plt.legend();
